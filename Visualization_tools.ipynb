# %% [markdown]
# <a href="https://colab.research.google.com/github/Katarivinaykumar/ML-/blob/main/Visualization_tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import random
x = []
y = []
[x.append(random.randint(5,25)) for _ in range(10)]
[y.append(random.randint(5,25)) for _ in range(10)]
print(x)
print(y)
plt.plot(x,y)
plt.scatter(x,y)
plt.bar(x,y)

[6, 20, 14, 25, 19, 7, 7, 21, 5, 20]
[7, 8, 20, 25, 20, 18, 23, 12, 14, 22]
# Out:
# [25, 12, 7, 21, 9, 24, 12, 22, 10, 23]
# [6, 23, 10, 23, 12, 12, 18, 11, 15, 15]
# [7, 8, 20, 25, 20, 18, 23, 12, 14, 22]
